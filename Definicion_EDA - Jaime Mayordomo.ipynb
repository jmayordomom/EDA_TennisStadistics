# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# **Tennistadistics**. Un estudio sobre las estadísticas dentro del mundo del tenis

# %% [markdown]
# ### TEMA

# %% [markdown]
# El tenis es un deporte que en los últimos años cada vez más está cogiendo fama, y la cantidad de datos e información asociados a este deporte crece a la misma velocidad

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# 1. Los tenistas europeos ganan de media más puntos que los del resto del mundo

# %% [markdown]
# 2. Los tenistas del top 4 ganan el 50% de los Master 1000

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Voy a utilizar 2 datasets:
# 1. Una API con datos sobre tenis (información de torneos, rankings de jugadores). [Tennis API 1](https://rapidapi.com/fluis.lacasse/api/tennisapi1/)
# 2. Una API de Kaggle con información de los partidos de los últimos 20 años. [ATP Tennis 2020-2023 Update](https://www.kaggle.com/code/dissfya/atp-tennis-daily-pull)

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import requests, json, pandas as pd

url = "https://tennisapi1.p.rapidapi.com/api/tennis/rankings/atp"

headers = {
	"X-RapidAPI-Key": "0b00932e03msh9c0e6292431999cp102f2cjsnfaa91f7ec449",
	"X-RapidAPI-Host": "tennisapi1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
todos = json.loads(response.text)
todos["rankings"]
pd.DataFrame(todos["rankings"]).drop(['team'], axis=1).head()
# Out:
#    tournamentsPlayed  type          rowName  ranking  points  previousRanking  \
# 0                 18     5   Novak Djokovic        1   11445                1
# 1                 17     5   Carlos Alcaraz        2    8455                2
# 2                 22     5  Daniil Medvedev        3    7200                3
# 3                 22     5    Jannik Sinner        4    5490                4
# 4                 25     5    Andrey Rublev        5    5205                5
#
#    previousPoints  bestRanking   id country rankingClass  \
# 0           11045            1  700      {}         team
# 1            8625            1  701      {}         team
# 2            7200            1  704      {}         team
# 3            5410            4  720      {}         team
# 4            4935            5  705      {}         team
#
#    bestRankingDateTimestamp
# 0              1.309738e+09
# 1                       NaN
# 2                       NaN
# 3                       NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\jaime\OneDrive\Documentos\Bootcamp\atp_tennis.csv', sep=";")
df
# Out:
#                                Tournament        Date         Series    Court  \
# 0      Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 1      Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 2      Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 3      Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 4      Australian Hardcourt Championships  03/01/2000  International  Outdoor
# ...                                   ...         ...            ...      ...
# 60320                      Stuttgart Open  16/06/2023         ATP250  Outdoor
# 60321                      Stuttgart Open  16/06/2023         ATP250  Outdoor
# 60322                      Stuttgart Open  17/06/2023         ATP250  Outdoor
# 60323                      Stuttgart Open  17/06/2023         ATP250  Outdoor
# 60324                      Stuttgart Open  18/06/2023         ATP250  Outdoor
#
# ...
