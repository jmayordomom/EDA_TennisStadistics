# %% [markdown]
# <p align="center">
#   <img src="../data/big_four.png">
# </p>

# %% [markdown]
# # TenisStadistics

# %% [markdown]
# ## Importamos librerías necesarias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy.stats as stats
import requests, json, numpy as np
import time
import sys

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Primer dataset
# ### CSV con los resultados de los partidos del circuito ATP desde el año 2000

# %% [markdown]
# #### Carga de datos

# %%
sys.path.append("../")
dfResultados = pd.read_csv("../data/raw/atp_tennis.csv", sep=";")
dfResultados.head()
# Out:
#                            Tournament        Date         Series    Court  \
# 0  Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 1  Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 2  Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 3  Australian Hardcourt Championships  03/01/2000  International  Outdoor
# 4  Australian Hardcourt Championships  03/01/2000  International  Outdoor
#
#   Surface      Round  Best of        Player_1       Player_2       Winner  \
# 0    Hard  1st Round        3      Dosedel S.    Ljubicic I.   Dosedel S.
# 1    Hard  1st Round        3      Clement A.     Enqvist T.   Enqvist T.
# 2    Hard  1st Round        3       Escude N.  Baccanello P.    Escude N.
# 3    Hard  1st Round        3  Knippschild J.     Federer R.   Federer R.
# 4    Hard  1st Round        3     Fromberg R.  Woodbridge T.  Fromberg R.
#
#    Rank_1  Rank_2  Pts_1  Pts_2 Odd_1 Odd_2           Score
# 0      63      77     -1     -1  -1.0  -1.0     6-4 6-2
# 1      56       5     -1     -1  -1.0  -1.0     3-6 3-6
# 2      40     655     -1     -1  -1.0  -1.0  6-7 7-5 6-3
# 3      87      65     -1     -1  -1.0  -1.0     1-6 4-6
# 4      81     198     -1     -1  -1.0  -1.0  7-6 5-7 6-4

# %%
dfResultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60325 entries, 0 to 60324
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tournament  60325 non-null  object
#  1   Date        60325 non-null  object
#  2   Series      60325 non-null  object
#  3   Court       60325 non-null  object
#  4   Surface     60325 non-null  object
#  5   Round       60325 non-null  object
#  6   Best of     60325 non-null  int64
#  7   Player_1    60325 non-null  object
#  8   Player_2    60325 non-null  object
#  9   Winner      60325 non-null  object
#  10  Rank_1      60325 non-null  int64
#  11  Rank_2      60325 non-null  int64
#  12  Pts_1       60325 non-null  int64
#  13  Pts_2       60325 non-null  int64
#  14  Odd_1       60325 non-null  object
#  15  Odd_2       60325 non-null  object
#  16  Score       60325 non-null  object
# dtypes: int64(5), object(12)
# memory usage: 7.8+ MB

# %%
dfResultados.describe().round(2)
# Out:
#         Best of    Rank_1    Rank_2     Pts_1     Pts_2
# count  60325.00  60325.00  60325.00  60325.00  60325.00
# mean       3.38     75.92     75.65   1083.27   1090.67
# std        0.78    100.77    101.73   1704.84   1730.70
# min        3.00     -1.00     -1.00     -1.00     -1.00
# 25%        3.00     25.00     24.00     -1.00     -1.00
# 50%        3.00     54.00     54.00    664.00    665.00
# 75%        3.00     92.00     92.00   1195.00   1205.00
# max        5.00   3390.00   4915.00  16950.00  16950.00

# %%
dfResultados.shape
# Out:
# (60325, 17)

# %% [markdown]
# #### Primer análisis de la información

# %%
dfResultados.isna().sum()/len(dfResultados) *100
# Out:
# Tournament    0.0
# Date          0.0
# Series        0.0
# Court         0.0
# Surface       0.0
# Round         0.0
# Best of       0.0
# Player_1      0.0
# Player_2      0.0
# Winner        0.0
# Rank_1        0.0
# Rank_2        0.0
# Pts_1         0.0
# Pts_2         0.0
# Odd_1         0.0
# Odd_2         0.0
# Score         0.0
# dtype: float64

# %% [markdown]
# Como no hay ningún valor NaN, no es necesario aplicar ningún tratamiento

# %% [markdown]
# ### Preparación de datos

# %%
#Eliminamos las columnas que no vamos a utilizar
dfResultados.drop(["Odd_1", "Odd_2", "Pts_1", "Pts_2"], axis=1, inplace=True)

#Convertimos el campo "Date" a tipo Date para un mejor tratamiento
dfResultados['Date'] = pd.to_datetime(dfResultados['Date'], format='%d/%m/%Y')
dfResultados
# Out:
#                                Tournament       Date         Series    Court  \
# 0      Australian Hardcourt Championships 2000-01-03  International  Outdoor
# 1      Australian Hardcourt Championships 2000-01-03  International  Outdoor
# 2      Australian Hardcourt Championships 2000-01-03  International  Outdoor
# 3      Australian Hardcourt Championships 2000-01-03  International  Outdoor
# 4      Australian Hardcourt Championships 2000-01-03  International  Outdoor
# ...                                   ...        ...            ...      ...
# 60320                      Stuttgart Open 2023-06-16         ATP250  Outdoor
# 60321                      Stuttgart Open 2023-06-16         ATP250  Outdoor
# 60322                      Stuttgart Open 2023-06-17         ATP250  Outdoor
# 60323                      Stuttgart Open 2023-06-17         ATP250  Outdoor
# 60324                      Stuttgart Open 2023-06-18         ATP250  Outdoor
#
#       Surface          Round  Best of        Player_1       Player_2  \
# 0        Hard      1st Round        3      Dosedel S.    Ljubicic I.
# 1        Hard      1st Round        3      Clement A.     Enqvist T.
# 2        Hard      1st Round        3       Escude N.  Baccanello P.
# 3        Hard      1st Round        3  Knippschild J.     Federer R.
# 4        Hard      1st Round        3     Fromberg R.  Woodbridge T.
# ...       ...            ...      ...             ...            ...
# 60320   Grass  Quarterfinals        3      Hurkacz H.   O Connell C.
# 60321   Grass  Quarterfinals        3      Gasquet R.    Struff J.L.
# 60322   Grass     Semifinals        3       Tiafoe F.   Fucsovics M.
# 60323   Grass     Semifinals        3      Hurkacz H.    Struff J.L.
# 60324   Grass      The Final        3       Tiafoe F.    Struff J.L.
#
#             Winner  Rank_1  Rank_2           Score
# 0       Dosedel S.      63      77     6-4 6-2
# 1       Enqvist T.      56       5     3-6 3-6
# 2        Escude N.      40     655  6-7 7-5 6-3
# 3       Federer R.      87      65     1-6 4-6
# 4      Fromberg R.      81     198  7-6 5-7 6-4
# ...            ...     ...     ...             ...
# 60320   Hurkacz H.      14      74     6-4 6-4
# 60321  Struff J.L.      55      24     4-6 5-7
# 60322    Tiafoe F.      12      86     6-3 7-6
# 60323  Struff J.L.      14      24  6-3 3-6 3-6
# 60324    Tiafoe F.      12      24  4-6 7-6 7-6
#
# [60325 rows x 13 columns]

# %%
df2023 = dfResultados[dfResultados["Date"].dt.year == 2023].reset_index()
df2023.head()
# Out:
#    index                Tournament       Date  Series    Court Surface  \
# 0  58955  Adelaide International 1 2023-01-01  ATP250  Outdoor    Hard
# 1  58956  Adelaide International 1 2023-01-02  ATP250  Outdoor    Hard
# 2  58957  Adelaide International 1 2023-01-02  ATP250  Outdoor    Hard
# 3  58958  Adelaide International 1 2023-01-02  ATP250  Outdoor    Hard
# 4  58959  Adelaide International 1 2023-01-02  ATP250  Outdoor    Hard
#
#        Round  Best of       Player_1            Player_2         Winner  \
# 0  1st Round        3     Gasquet R.            Giron M.       Giron M.
# 1  1st Round        3  Kecmanovic M.        O Connell C.  Kecmanovic M.
# 2  1st Round        3        Rune H.         Nishioka Y.    Nishioka Y.
# 3  1st Round        3     Popyrin A.  Auger-Aliassime F.     Popyrin A.
# 4  1st Round        3    Thompson J.            Halys Q.       Halys Q.
#
#    Rank_1  Rank_2           Score
# 0      68      61  6-7 7-6 5-7
# 1      29      78     6-4 6-4
# 2      11      36  6-2 4-6 4-6
# 3     120       6     6-4 7-6
# 4      84      64     3-6 4-6

# %%
torneos = ['Grand Slam', "Masters Cup", 'Masters 1000']
df_torneos = df2023[df2023["Series"].isin(torneos)]

df_torneos["Sets_Played"] = df_torneos["Score"].str.count("-")
df_torneos["Tie_Breaks"] = df_torneos["Score"].str.count("7-6") + df_torneos["Score"].str.count("6-7")
df_torneos.set_index("index", inplace=True)
df_torneos.head()
# Out:
# C:\Users\jaime\AppData\Local\Temp\ipykernel_19752\1898467528.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_torneos["Sets_Played"] = df_torneos["Score"].str.count("-")
# C:\Users\jaime\AppData\Local\Temp\ipykernel_19752\1898467528.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_torneos["Tie_Breaks"] = df_torneos["Score"].str.count("7-6") + df_torneos["Score"].str.count("6-7")
#             Tournament       Date      Series    Court Surface      Round  \
# index
# 59060  Australian Open 2023-01-16  Grand Slam  Outdoor    Hard  1st Round
# 59061  Australian Open 2023-01-16  Grand Slam  Outdoor    Hard  1st Round
# 59062  Australian Open 2023-01-16  Grand Slam  Outdoor    Hard  1st Round
# 59063  Australian Open 2023-01-16  Grand Slam  Outdoor    Hard  1st Round
# 59064  Australian Open 2023-01-16  Grand Slam  Outdoor    Hard  1st Round
#
#        Best of              Player_1       Player_2                Winner  \
# index
# 59060        5             Moutet C.          Wu Y.             Moutet C.
# 59061        5        Rinderknech A.    Watanuki Y.           Watanuki Y.
# 59062        5  Van De Zandschulp B.     Ivashka I.  Van De Zandschulp B.
# 59063        5            Barrere G.  Etcheverry T.         Etcheverry T.
# 59064        5             Sinner J.      Edmund K.             Sinner J.
#
#        Rank_1  Rank_2                 Score  Sets_Played  Tie_Breaks
# index
# 59060      62     114  6-4 5-7 6-2 4-6 7-5             5           0
# 59061      59     138        3-6 3-6 2-6               3           0
# 59062      34      73     6-3 3-6 7-5 6-3              4           0
# 59063      83      79     6-3 3-6 4-6 4-6              4           0
# 59064      16     581        6-4 6-0 6-2               3           0

# %%
df_torneos.to_csv(r"../data/final/atp_tennis_final.csv")

# %% [markdown]
# ### Descripción de columnas de dataframe
# | Columnas | Descripción |
# |----------|----------|
# | Tournament | Nombre del torneo
# |Date|Fecha del partido
# |Series|Categoría del torneo
# |Court|Si se juega en interior o exterior
# |Surface|Tipo de superficie donde se juega el torneo
# |Best of|Al mejor de que sets se juega
# |Player_1|Jugador 1
# |Player_2|Jugador 2
# |Winner|Ganador del partido
# |Rank_1|Ranking del jugador 1 al comienzo de ese torneo
# |Rank_2|Ranking del jugador 2 al comienzo de ese torneo
# |Score|Puntuación del partido
# |Sets_Played|Número de sets jugados
# |Tie_Breaks|Número de Tie-Breaks del partido

# %% [markdown]
# ### Análisis univariante

# %%
df_torneos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 666 entries, 59060 to 60272
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tournament   666 non-null    object
#  1   Date         666 non-null    datetime64[ns]
#  2   Series       666 non-null    object
#  3   Court        666 non-null    object
#  4   Surface      666 non-null    object
#  5   Round        666 non-null    object
#  6   Best of      666 non-null    int64
#  7   Player_1     666 non-null    object
#  8   Player_2     666 non-null    object
#  9   Winner       666 non-null    object
#  10  Rank_1       666 non-null    int64
#  11  Rank_2       666 non-null    int64
#  12  Score        666 non-null    object
#  13  Sets_Played  666 non-null    int64
#  14  Tie_Breaks   666 non-null    int64
# dtypes: datetime64[ns](1), int64(5), object(9)
# memory usage: 83.2+ KB

# %%
df_torneos.describe(include="int64").round(2)
# Out:
#        Best of  Rank_1  Rank_2  Sets_Played  Tie_Breaks
# count   666.00  666.00  666.00       666.00      666.00
# mean      3.74   66.39   67.30         2.89        0.53
# std       0.97   72.60   88.06         0.93        0.71
# min       3.00    1.00    1.00         2.00        0.00
# 25%       3.00   18.00   19.00         2.00        0.00
# 50%       3.00   54.00   49.00         3.00        0.00
# 75%       5.00   92.00   87.00         3.00        1.00
# max       5.00  675.00  894.00         5.00        3.00

# %%
for i in df_torneos.select_dtypes(include=object):
    print(f"La cardinalidad de la variable {i} es {(df_torneos[i].nunique()/df_torneos.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable Tournament es 1.05%
# La cardinalidad de la variable Series es 0.30%
# La cardinalidad de la variable Court es 0.15%
# La cardinalidad de la variable Surface es 0.30%
# La cardinalidad de la variable Round es 1.05%
# La cardinalidad de la variable Player_1 es 23.72%
# La cardinalidad de la variable Player_2 es 22.37%
# La cardinalidad de la variable Winner es 19.82%
# La cardinalidad de la variable Score es 66.37%

# %%
color = "#FFC114"
df_torneos.hist(figsize=(15,15),grid=False,color=color);

# %%
#Número de partidos ganados en total
winners = df_torneos.groupby("Winner").count().sort_values("Series", ascending=False).head(5).index
victorias = df_torneos.groupby("Winner").count().sort_values("Series", ascending=False).head(5)["Series"]

color = ['blue', 'orange', 'purple', 'red', 'green']

plt.barh(winners, victorias, color=color)
plt.title("Número de partidos ganados")
plt.show()

# %%
df_Finales = df_torneos[df_torneos["Round"] == "The Final"]
ganaFinal = df_Finales["Winner"].value_counts()
plt.figure(figsize = (6,6))
plt.pie(ganaFinal.values,
       labels = ganaFinal.index,
       autopct='%1.2f%%');

# %% [markdown]
# ### Análisis multivariante

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df_torneos.corr(numeric_only=True), annot=True);

# %% [markdown]
# ## Segundo dataset
# ### API que contiene estadísticas de jugadores

# %% [markdown]
# ### Carga de datos

# %%
url = "https://ultimate-tennis1.p.rapidapi.com/live_leaderboard/50"

headers = {
	"X-RapidAPI-Key": "0b00932e03msh9c0e6292431999cp102f2cjsnfaa91f7ec449",
	"X-RapidAPI-Host": "ultimate-tennis1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

todos = json.loads(response.text)

players = pd.DataFrame(todos["data"])

# %%
ids = players[["Name","id"]]

# %%
dfStats = pd.DataFrame()

for i in range(len(ids)):
	id = ids.iloc[i]["id"]
	name = ids.iloc[i]["Name"]
	# print(id, name)
	url = (f"https://ultimate-tennis1.p.rapidapi.com/player_stats/atp/{id}/2023/all")

	headers = {
		"X-RapidAPI-Key": "0b00932e03msh9c0e6292431999cp102f2cjsnfaa91f7ec449",
		"X-RapidAPI-Host": "ultimate-tennis1.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers)

	playerStats = json.loads(response.text)

	data1 = pd.DataFrame(playerStats["player_data"]).head()
	# print(data1)

	name = pd.DataFrame([name], columns=["Name"])
	conc = pd.concat([name, data1], axis=1)
	dfStats = pd.concat([dfStats, conc], ignore_index=True)
	time.sleep(5)
dfStats.head()
# Out:
# d643 Novak Djokovic
# a0e2 Carlos Alcaraz
# mm58 Daniil Medvedev
# s0ag Jannik Sinner
# re44 Andrey Rublev
# te51 Stefanos Tsitsipas
# z355 Alexander Zverev
# r0dg Holger Rune
# hb71 Hubert Hurkacz
# fb98 Taylor Fritz
# rh16 Casper Ruud
# dh58 Alex de Minaur
# pl56 Tommy Paul
# d875 Grigor Dimitrov
# ke29 Karen Khachanov
# td51 Frances Tiafoe
# s0s1 Ben Shelton
# n771 Cameron Norrie
# j551 Nicolas Jarry
# hh26 Ugo Humbert
# c0au Francisco Cerundolo
# me82 Adrian Mannarino
# gj37 Tallon Griekspoor
# k0ah Sebastian Korda
# sl28 Jan-Lennard Struff
# dh50 Alejandro Davidovich Fokina
# m0ej Lorenzo Musetti
# b0bi Sebastian Baez
# ag37 Felix Auger-Aliassime
# ea24 Tomas Martin Etcheverry
# l0bv Jiri Lehecka
# bk92 Alexander Bublik
# db63 Laslo Djere
# e865 Christopher Eubanks
# kc56 Aslan Karatsev
# f0f1 Arthur Fils
# cg80 Borna Coric
# e687 Daniel Evans
# sx50 Roman Safiullin
# p09z Alexei Popyrin
# mk66 Mackenzie McDonald
# mc10 Andy Murray
# o513 Sebastian Ofner
# a0fc Matteo Arnaldi
# ph71 Max Purcell
# su87 Lorenzo Sonego
# n732 Yoshihito Nishioka
# s0h2 Alexander Shevchenko
# w367 Stan Wawrinka
# v812 Botic van de Zandschulp
#                            Name 1st Serve 1st Serve Points Won  \
# 0                Novak Djokovic       64%                  76%
# 1                Carlos Alcaraz       66%                  72%
# 2               Daniil Medvedev       64%                  75%
# 3                 Jannik Sinner       60%                  76%
# 4                 Andrey Rublev       61%                  75%
# 5            Stefanos Tsitsipas       64%                  78%
# 6              Alexander Zverev       71%                  74%
# 7                   Holger Rune       62%                  72%
# 8                Hubert Hurkacz       64%                  80%
# 9                  Taylor Fritz       59%                  79%
# 10                  Casper Ruud       63%                  71%
# 11               Alex de Minaur       56%                  72%
# 12                   Tommy Paul       62%                  72%
# 13              Grigor Dimitrov       61%                  77%
# 14              Karen Khachanov       64%                  74%
# 15               Frances Tiafoe       60%                  77%
# 16                  Ben Shelton       64%                  76%
# 17               Cameron Norrie       65%                  70%
# 18                Nicolas Jarry       65%                  77%
# 19                  Ugo Humbert       60%                  74%
# 20          Francisco Cerundolo       66%                  67%
# 21             Adrian Mannarino       61%                  71%
# 22            Tallon Griekspoor       63%                  76%
# 23              Sebastian Korda       62%                  74%
# 24           Jan-Lennard Struff       59%                  75%
# 25  Alejandro Davidovich Fokina       66%                  67%
# 26              Lorenzo Musetti       62%                  71%
# 27               Sebastian Baez       72%                  65%
# 28        Felix Auger-Aliassime       60%                  78%
# 29      Tomas Martin Etcheverry       64%                  71%
# 30                 Jiri Lehecka       65%                  72%
# 31             Alexander Bublik       59%                  79%
# 32                  Laslo Djere       61%                  72%
# 33          Christopher Eubanks       69%                  74%
# 34               Aslan Karatsev       59%                  75%
# 35                  Arthur Fils       61%                  74%
# 36                  Borna Coric       60%                  74%
# 37                 Daniel Evans       59%                  71%
# 38              Roman Safiullin       64%                  73%
# 39               Alexei Popyrin       62%                  76%
# 40           Mackenzie McDonald       64%                  69%
# 41                  Andy Murray       61%                  71%
# 42              Sebastian Ofner       57%                  71%
# 43               Matteo Arnaldi       58%                  69%
# 44                  Max Purcell       60%                  72%
# 45               Lorenzo Sonego       66%                  73%
# 46           Yoshihito Nishioka       63%                  65%
# 47         Alexander Shevchenko       59%                  69%
# 48                Stan Wawrinka       56%                  76%
# 49      Botic van de Zandschulp       63%                  69%
#
#    1st Serve Return Points Won 2nd Serve Points Won  \
# 0                          33%                  58%
# 1                          35%                  56%
# 2                          34%                  50%
# 3                          33%                  57%
# 4                          30%                  51%
# 5                          27%                  55%
# 6                          29%                  50%
# 7                          29%                  53%
# 8                          27%                  51%
# 9                          28%                  55%
# 10                         30%                  54%
# 11                         34%                  54%
# 12                         30%                  53%
# 13                         30%                  51%
# 14                         30%                  53%
# 15                         27%                  53%
# 16                         26%                  52%
# 17                         31%                  53%
# 18                         28%                  54%
# 19                         29%                  51%
# 20                         33%                  49%
# 21                         29%                  53%
# 22                         27%                  51%
# 23                         26%                  54%
# 24                         26%                  50%
# 25                         31%                  53%
# 26                         32%                  51%
# 27                         31%                  54%
# 28                         28%                  49%
# 29                         30%                  53%
# 30                         28%                  51%
# 31                         25%                  46%
# 32                         27%                  52%
# 33                         22%                  52%
# 34                         27%                  50%
# 35                         28%                  50%
# 36                         29%                  49%
# 37                         30%                  52%
# 38                         29%                  52%
# 39                         26%                  50%
# 40                         29%                  51%
# 41                         29%                  51%
# 42                         29%                  47%
# 43                         28%                  54%
# 44                         27%                  47%
# 45                         27%                  52%
# 46                         26%                  55%
# 47                         27%                  50%
# 48                         27%                  54%
# 49                         31%                  47%
#
#    2nd Serve Return Points Won   Aces Break Points Converted  \
# 0                          54%    383                    42%
# 1                          54%    302                    40%
# 2                          54%    547                    46%
# 3                          54%    436                    42%
# 4                          52%    616                    39%
# 5                          49%    547                    39%
# 6                          52%    613                    37%
# 7                          49%    359                    39%
# 8                          46%  1,031                    35%
# 9                          53%    692                    42%
# 10                         51%    320                    39%
# 11                         52%    229                    43%
# 12                         51%    411                    37%
# 13                         51%    461                    41%
# 14                         51%    362                    41%
# 15                         51%    459                    38%
# 16                         44%    505                    41%
# 17                         51%    272                    40%
# 18                         48%    475                    38%
# 19                         50%    341                    36%
# 20                         51%    185                    40%
# 21                         52%    317                    47%
# 22                         46%    466                    38%
# 23                         51%    355                    41%
# 24                         49%    360                    38%
# 25                         53%    175                    45%
# 26                         51%    224                    43%
# 27                         53%     97                    41%
# 28                         47%    380                    32%
# 29                         50%    344                    36%
# 30                         47%    265                    38%
# 31                         47%    543                    41%
# 32                         50%    335                    38%
# 33                         46%    498                    35%
# 34                         47%    258                    38%
# 35                         49%    245                    38%
# 36                         45%    159                    35%
# 37                         48%    167                    37%
# 38                         50%    230                    44%
# 39                         46%    466                    32%
# 40                         53%    262                    43%
# 41                         50%    153                    32%
# 42                         51%    160                    40%
# 43                         52%    167                    41%
# 44                         46%    231                    37%
# 45                         47%    297                    39%
# 46                         52%     85                    39%
# 47                         49%    140                    41%
# 48                         47%    362                    39%
# 49                         50%    239                    36%
#
#    Break Points Faced Break Points Opportunities Break Points Saved  \
# 0                 261                        491                67%
# 1                 369                        691                65%
# 2                 419                        622                67%
# 3                 368                        615                69%
# 4                 439                        639                63%
# 5                 312                        469                66%
# 6                 406                        618                64%
# 7                 395                        453                64%
# 8                 334                        460                64%
# 9                 352                        490                66%
# 10                396                        466                67%
# 11                374                        518                59%
# 12                395                        527                62%
# 13                337                        451                63%
# 14                275                        367                63%
# 15                275                        399                66%
# 16                298                        256                66%
# 17                401                        454                64%
# 18                273                        316                68%
# 19                315                        392                62%
# 20                478                        546                61%
# 21                393                        421                61%
# 22                277                        303                65%
# 23                225                        253                64%
# 24                239                        233                66%
# 25                411                        404                62%
# 26                335                        412                58%
# 27                332                        360                58%
# 28                212                        279                60%
# 29                354                        423                63%
# 30                321                        303                63%
# 31                278                        236                61%
# 32                358                        356                65%
# 33                247                        205                65%
# 34                265                        247                65%
# 35                224                        234                63%
# 36                224                        207                59%
# 37                272                        270                61%
# 38                234                        232                62%
# 39                284                        291                66%
# 40                335                        344                59%
# 41                228                        256                61%
# 42                218                        188                58%
# 43                249                        191                69%
# 44                223                        155                67%
# 45                326                        294                65%
# 46                286                        292                53%
# 47                246                        206                60%
# 48                278                        302                64%
# 49                354                        335                62%
#
#    Double Faults Return Games Played Return Games Won Return Points Won  \
# 0            157                 721              29%               41%
# 1            161                 874              32%               42%
# 2            314                 922              31%               41%
# 3            129                 892              29%               41%
# 4            156               1,029              24%               38%
# 5            153                 926              20%               35%
# 6            222                 970              23%               38%
# 7            259                 830              21%               37%
# 8            133                 985              16%               34%
# 9            165                 909              23%               38%
# 10           167                 772              23%               38%
# 11           177                 773              29%               41%
# 12           143                 812              24%               38%
# 13           212                 758              24%               38%
# 14            99                 639              23%               38%
# 15           125                 699              22%               37%
# 16           209                 675              16%               32%
# 17           127                 718              25%               39%
# 18           108                 700              17%               35%
# 19           140                 633              22%               37%
# 20           218                 776              28%               40%
# 21           144                 777              26%               38%
# 22           181                 699              16%               34%
# 23            93                 520              20%               36%
# 24           132                 478              19%               35%
# 25           102                 684              26%               39%
# 26           144                 675              26%               39%
# 27            80                 553              27%               39%
# 28           200                 531              17%               35%
# 29            92                 705              22%               38%
# 30           113                 616              19%               35%
# 31           364                 598              16%               34%
# 32           152                 672              20%               36%
# 33           128                 584              12%               31%
# 34           212                 509              19%               35%
# 35           126                 456              20%               35%
# 36            70                 430              17%               35%
# 37           121                 485              21%               37%
# 38           135                 473              22%               37%
# 39           134                 617              15%               33%
# 40           127                 622              24%               38%
# 41            74                 446              19%               36%
# 42            86                 342              22%               37%
# 43            99                 389              20%               37%
# 44            65                 340              17%               34%
# 45           109                 665              17%               35%
# 46            77                 530              21%               36%
# 47            84                 398              21%               36%
# 48            88                 591              20%               35%
# 49           151                 530              23%               38%
#
#    Service Games Played Service Games Won Total Points Won  \
# 0                   741               88%              55%
# 1                   881               85%              54%
# 2                   923               85%              54%
# 3                   901               87%              54%
# 4                 1,038               84%              52%
# 5                   942               89%              52%
# 6                   964               85%              52%
# 7                   833               83%              51%
# 8                   999               88%              51%
# 9                   935               87%              53%
# 10                  783               83%              51%
# 11                  764               80%              52%
# 12                  816               81%              51%
# 13                  774               84%              52%
# 14                  643               84%              52%
# 15                  688               86%              52%
# 16                  674               85%              50%
# 17                  728               80%              51%
# 18                  703               88%              52%
# 19                  649               81%              51%
# 20                  764               76%              50%
# 21                  771               80%              51%
# 22                  696               86%              51%
# 23                  517               84%              51%
# 24                  472               83%              50%
# 25                  684               77%              51%
# 26                  669               79%              51%
# 27                  548               75%              50%
# 28                  539               84%              51%
# 29                  708               81%              51%
# 30                  619               81%              50%
# 31                  597               82%              50%
# 32                  667               81%              50%
# 33                  598               86%              50%
# 34                  520               82%              50%
# 35                  461               82%              50%
# 36                  426               78%              49%
# 37                  479               78%              50%
# 38                  481               81%              51%
# 39                  615               84%              50%
# 40                  620               78%              50%
# 41                  445               80%              50%
# 42                  340               73%              49%
# 43                  396               80%              50%
# 44                  334               78%              48%
# 45                  665               83%              50%
# 46                  524               74%              49%
# 47                  399               75%              49%
# 48                  602               83%              51%
# 49                  529               75%              50%
#
#    Total Service Points Won
# 0                       70%
# 1                       67%
# 2                       66%
# 3                       68%
# 4                       66%
# 5                       70%
# 6                       67%
# 7                       65%
# 8                       69%
# 9                       69%
# 10                      65%
# 11                      64%
# 12                      65%
# 13                      67%
# 14                      66%
# 15                      67%
# 16                      67%
# 17                      64%
# 18                      69%
# 19                      65%
# 20                      61%
# 21                      64%
# 22                      67%
# 23                      67%
# 24                      65%
# 25                      62%
# 26                      63%
# 27                      62%
# 28                      67%
# 29                      65%
# 30                      65%
# 31                      65%
# 32                      64%
# 33                      67%
# 34                      65%
# 35                      65%
# 36                      64%
# 37                      63%
# 38                      65%
# 39                      66%
# 40                      63%
# 41                      64%
# 42                      61%
# 43                      63%
# 44                      62%
# 45                      66%
# 46                      62%
# 47                      61%
# 48                      66%
# 49                      61%

# %% [markdown]
# ### Primer análisis

# %%
dfStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         50 non-null     object
#  1   1st Serve                    50 non-null     object
#  2   1st Serve Points Won         50 non-null     object
#  3   1st Serve Return Points Won  50 non-null     object
#  4   2nd Serve Points Won         50 non-null     object
#  5   2nd Serve Return Points Won  50 non-null     object
#  6   Aces                         50 non-null     object
#  7   Break Points Converted       50 non-null     object
#  8   Break Points Faced           50 non-null     object
#  9   Break Points Opportunities   50 non-null     object
#  10  Break Points Saved           50 non-null     object
#  11  Double Faults                50 non-null     object
#  12  Return Games Played          50 non-null     object
#  13  Return Games Won             50 non-null     object
#  14  Return Points Won            50 non-null     object
#  15  Service Games Played         50 non-null     object
#  16  Service Games Won            50 non-null     object
#  17  Total Points Won             50 non-null     object
#  18  Total Service Points Won     50 non-null     object
# dtypes: object(19)
# memory usage: 7.6+ KB

# %%
dfStats.describe()
# Out:
#                   Name 1st Serve 1st Serve Points Won  \
# count               50        50                   50
# unique              50        14                   14
# top     Novak Djokovic       64%                  72%
# freq                 1         9                    7
#
#        1st Serve Return Points Won 2nd Serve Points Won  \
# count                           50                   50
# unique                          12                   12
# top                            27%                  51%
# freq                            10                    9
#
#        2nd Serve Return Points Won Aces Break Points Converted  \
# count                           50   50                     50
# unique                          11   46                     14
# top                            51%  362                    41%
# freq                            10    2                      8
#
#        Break Points Faced Break Points Opportunities Break Points Saved  \
# count                  50                         50                 50
# unique                 44                         48                 13
# top                   335                        303                65%
# freq                    2                          2                  6
#
#        Double Faults Return Games Played Return Games Won Return Points Won  \
# count             50                  50               50                50
# unique            46                  47               17                12
# top              212                 530              20%               38%
# freq               2                   2                6                11
#
#        Service Games Played Service Games Won Total Points Won  \
# count                    50                50               50
# unique                   49                17                8
# top                     764               84%              50%
# freq                      2                 6               17
#
#        Total Service Points Won
# count                        50
# unique                       10
# top                         65%
# freq                         11

# %% [markdown]
# ### Preparación de los datos

# %%
dfStats = dfStats.set_axis(["Player Name", "First serve", "First Serve Points Won", "1st Serve Return Points Won", "2nd Serve Points Won","2nd Serve Return Points Won",
                            "Aces","Break Points Converted", "Break Points Faced", "Break Points Opportunities", "Break Points Saved", "Double Faults",
                            "Return Games Played", "Return Games Won %", "Return Points Won", "Service Games Played", "Service Games Won %", "Total Points Won",
                            "Total Service Points Won"], axis=1)
dfStats.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 dfStats = dfStats.set_axis(["Player Name", "First serve", "First Serve Points Won", "1st Serve Return Points Won", "2nd Serve Points Won","2nd Serve Return Points Won",
#       2                             "Aces","Break Points Converted", "Break Points Faced", "Break Points Opportunities", "Break Points Saved", "Double Faults",
#       3                             "Return Games Played", "Return Games Won %", "Return Points Won", "Service Games Played", "Service Games Won %", "Total Points Won",
#       4                             "Total Service Points Won"], axis=1)
#       5 dfStats.head()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5123, in DataFrame.set_axis(self, labels, axis, copy)
#    5085 @Appender(
#    5086     """
#    5087     Examples
#    (...)
#    5121     copy: bool | None = None,
#    5122 ) -> DataFrame:
# -> 5123     return super().set_axis(labels, axis=axis, copy=copy)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:745, in NDFrame.set_axis(self, labels, axis, copy)
#     709 def set_axis(
#     710     self,
#     711     labels,
#    (...)
#     714     copy: bool_t | None = None,
#     715 ) -> Self:
#     716     """
#     717     Assign desired index to given axis.
#     718
#    (...)
#     743     %(klass)s.rename_axis : Alter the name of the index%(see_also_sub)s.
#     744     """
# --> 745     return self._set_axis_nocheck(labels, axis, inplace=False, copy=copy)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:757, in NDFrame._set_axis_nocheck(self, labels, axis, inplace, copy)
#     753 else:
#     754     # With copy=False, we create a new object but don't copy the
#     755     #  underlying data.
#     756     obj = self.copy(deep=copy and not using_copy_on_write())
# --> 757     setattr(obj, obj._get_axis_name(axis), labels)
#     758     return obj
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 23 elements, new values have 19 elements

# %%
dfStats['First serve'] = dfStats['First serve'].str.rstrip('%').astype('float') / 100.0
dfStats['First Serve Points Won'] = dfStats['First Serve Points Won'].str.rstrip('%').astype('float') / 100.0
dfStats['2nd Serve Points Won'] = dfStats['2nd Serve Points Won'].str.rstrip('%').astype('float') / 100.0
dfStats['Break Points Converted'] = dfStats['Break Points Converted'].str.rstrip('%').astype('float') / 100.0
dfStats['Break Points Saved'] = dfStats['Break Points Saved'].str.rstrip('%').astype('float') / 100.0
dfStats['Return Games Won %'] = dfStats['Return Games Won %'].str.rstrip('%').astype('float') / 100.0
dfStats['Return Points Won'] = dfStats['Return Points Won'].str.rstrip('%').astype('float') / 100.0
dfStats['Service Games Won %'] = dfStats['Service Games Won %'].str.rstrip('%').astype('float') / 100.0
dfStats['Total Service Points Won'] = dfStats['Total Service Points Won'].str.rstrip('%').astype('float') / 100.0
dfStats['Total Points Won'] = dfStats['Total Points Won'].str.rstrip('%').astype('float') / 100.0
dfStats.head()
# Out:
#                     Player Name  First serve  First Serve Points Won  \
# 0                Novak Djokovic         0.64                    0.76
# 1                Carlos Alcaraz         0.66                    0.72
# 2               Daniil Medvedev         0.64                    0.75
# 3                 Jannik Sinner         0.60                    0.76
# 4                 Andrey Rublev         0.61                    0.75
# 5            Stefanos Tsitsipas         0.64                    0.78
# 6              Alexander Zverev         0.71                    0.74
# 7                   Holger Rune         0.62                    0.72
# 8                Hubert Hurkacz         0.64                    0.80
# 9                  Taylor Fritz         0.59                    0.79
# 10                  Casper Ruud         0.63                    0.71
# 11               Alex de Minaur         0.56                    0.72
# 12                   Tommy Paul         0.62                    0.72
# 13              Grigor Dimitrov         0.61                    0.77
# 14              Karen Khachanov         0.64                    0.74
# 15               Frances Tiafoe         0.60                    0.77
# 16                  Ben Shelton         0.64                    0.76
# 17               Cameron Norrie         0.65                    0.70
# 18                Nicolas Jarry         0.65                    0.77
# 19                  Ugo Humbert         0.60                    0.74
# 20          Francisco Cerundolo         0.66                    0.67
# 21             Adrian Mannarino         0.61                    0.71
# 22            Tallon Griekspoor         0.63                    0.76
# 23              Sebastian Korda         0.62                    0.74
# 24           Jan-Lennard Struff         0.59                    0.75
# 25  Alejandro Davidovich Fokina         0.66                    0.67
# 26              Lorenzo Musetti         0.62                    0.71
# 27               Sebastian Baez         0.72                    0.65
# 28        Felix Auger-Aliassime         0.60                    0.78
# 29      Tomas Martin Etcheverry         0.64                    0.71
# 30                 Jiri Lehecka         0.65                    0.72
# 31             Alexander Bublik         0.59                    0.79
# 32                  Laslo Djere         0.61                    0.72
# 33          Christopher Eubanks         0.69                    0.74
# 34               Aslan Karatsev         0.59                    0.75
# 35                  Arthur Fils         0.61                    0.74
# 36                  Borna Coric         0.60                    0.74
# 37                 Daniel Evans         0.59                    0.71
# 38              Roman Safiullin         0.64                    0.73
# 39               Alexei Popyrin         0.62                    0.76
# 40           Mackenzie McDonald         0.64                    0.69
# 41                  Andy Murray         0.61                    0.71
# 42              Sebastian Ofner         0.57                    0.71
# 43               Matteo Arnaldi         0.58                    0.69
# 44                  Max Purcell         0.60                    0.72
# 45               Lorenzo Sonego         0.66                    0.73
# 46           Yoshihito Nishioka         0.63                    0.65
# 47         Alexander Shevchenko         0.59                    0.69
# 48                Stan Wawrinka         0.56                    0.76
# 49      Botic van de Zandschulp         0.63                    0.69
#
#    1st Serve Return Points Won  2nd Serve Points Won  \
# 0                          33%                  0.58
# 1                          35%                  0.56
# 2                          34%                  0.50
# 3                          33%                  0.57
# 4                          30%                  0.51
# 5                          27%                  0.55
# 6                          29%                  0.50
# 7                          29%                  0.53
# 8                          27%                  0.51
# 9                          28%                  0.55
# 10                         30%                  0.54
# 11                         34%                  0.54
# 12                         30%                  0.53
# 13                         30%                  0.51
# 14                         30%                  0.53
# 15                         27%                  0.53
# 16                         26%                  0.52
# 17                         31%                  0.53
# 18                         28%                  0.54
# 19                         29%                  0.51
# 20                         33%                  0.49
# 21                         29%                  0.53
# 22                         27%                  0.51
# 23                         26%                  0.54
# 24                         26%                  0.50
# 25                         31%                  0.53
# 26                         32%                  0.51
# 27                         31%                  0.54
# 28                         28%                  0.49
# 29                         30%                  0.53
# 30                         28%                  0.51
# 31                         25%                  0.46
# 32                         27%                  0.52
# 33                         22%                  0.52
# 34                         27%                  0.50
# 35                         28%                  0.50
# 36                         29%                  0.49
# 37                         30%                  0.52
# 38                         29%                  0.52
# 39                         26%                  0.50
# 40                         29%                  0.51
# 41                         29%                  0.51
# 42                         29%                  0.47
# 43                         28%                  0.54
# 44                         27%                  0.47
# 45                         27%                  0.52
# 46                         26%                  0.55
# 47                         27%                  0.50
# 48                         27%                  0.54
# 49                         31%                  0.47
#
#    2nd Serve Return Points Won   Aces  Break Points Converted  \
# 0                          54%    383                    0.42
# 1                          54%    302                    0.40
# 2                          54%    547                    0.46
# 3                          54%    436                    0.42
# 4                          52%    616                    0.39
# 5                          49%    547                    0.39
# 6                          52%    613                    0.37
# 7                          49%    359                    0.39
# 8                          46%  1,031                    0.35
# 9                          53%    692                    0.42
# 10                         51%    320                    0.39
# 11                         52%    229                    0.43
# 12                         51%    411                    0.37
# 13                         51%    461                    0.41
# 14                         51%    362                    0.41
# 15                         51%    459                    0.38
# 16                         44%    505                    0.41
# 17                         51%    272                    0.40
# 18                         48%    475                    0.38
# 19                         50%    341                    0.36
# 20                         51%    185                    0.40
# 21                         52%    317                    0.47
# 22                         46%    466                    0.38
# 23                         51%    355                    0.41
# 24                         49%    360                    0.38
# 25                         53%    175                    0.45
# 26                         51%    224                    0.43
# 27                         53%     97                    0.41
# 28                         47%    380                    0.32
# 29                         50%    344                    0.36
# 30                         47%    265                    0.38
# 31                         47%    543                    0.41
# 32                         50%    335                    0.38
# 33                         46%    498                    0.35
# 34                         47%    258                    0.38
# 35                         49%    245                    0.38
# 36                         45%    159                    0.35
# 37                         48%    167                    0.37
# 38                         50%    230                    0.44
# 39                         46%    466                    0.32
# 40                         53%    262                    0.43
# 41                         50%    153                    0.32
# 42                         51%    160                    0.40
# 43                         52%    167                    0.41
# 44                         46%    231                    0.37
# 45                         47%    297                    0.39
# 46                         52%     85                    0.39
# 47                         49%    140                    0.41
# 48                         47%    362                    0.39
# 49                         50%    239                    0.36
#
#    Break Points Faced Break Points Opportunities  Break Points Saved  \
# 0                 261                        491                0.67
# 1                 369                        691                0.65
# 2                 419                        622                0.67
# 3                 368                        615                0.69
# 4                 439                        639                0.63
# 5                 312                        469                0.66
# 6                 406                        618                0.64
# 7                 395                        453                0.64
# 8                 334                        460                0.64
# 9                 352                        490                0.66
# 10                396                        466                0.67
# 11                374                        518                0.59
# 12                395                        527                0.62
# 13                337                        451                0.63
# 14                275                        367                0.63
# 15                275                        399                0.66
# 16                298                        256                0.66
# 17                401                        454                0.64
# 18                273                        316                0.68
# 19                315                        392                0.62
# 20                478                        546                0.61
# 21                393                        421                0.61
# 22                277                        303                0.65
# 23                225                        253                0.64
# 24                239                        233                0.66
# 25                411                        404                0.62
# 26                335                        412                0.58
# 27                332                        360                0.58
# 28                212                        279                0.60
# 29                354                        423                0.63
# 30                321                        303                0.63
# 31                278                        236                0.61
# 32                358                        356                0.65
# 33                247                        205                0.65
# 34                265                        247                0.65
# 35                224                        234                0.63
# 36                224                        207                0.59
# 37                272                        270                0.61
# 38                234                        232                0.62
# 39                284                        291                0.66
# 40                335                        344                0.59
# 41                228                        256                0.61
# 42                218                        188                0.58
# 43                249                        191                0.69
# 44                223                        155                0.67
# 45                326                        294                0.65
# 46                286                        292                0.53
# 47                246                        206                0.60
# 48                278                        302                0.64
# 49                354                        335                0.62
#
#    Double Faults Return Games Played  Return Games Won %  Return Points Won  \
# 0            157                 721                0.29               0.41
# 1            161                 874                0.32               0.42
# 2            314                 922                0.31               0.41
# 3            129                 892                0.29               0.41
# 4            156               1,029                0.24               0.38
# 5            153                 926                0.20               0.35
# 6            222                 970                0.23               0.38
# 7            259                 830                0.21               0.37
# 8            133                 985                0.16               0.34
# 9            165                 909                0.23               0.38
# 10           167                 772                0.23               0.38
# 11           177                 773                0.29               0.41
# 12           143                 812                0.24               0.38
# 13           212                 758                0.24               0.38
# 14            99                 639                0.23               0.38
# 15           125                 699                0.22               0.37
# 16           209                 675                0.16               0.32
# 17           127                 718                0.25               0.39
# 18           108                 700                0.17               0.35
# 19           140                 633                0.22               0.37
# 20           218                 776                0.28               0.40
# 21           144                 777                0.26               0.38
# 22           181                 699                0.16               0.34
# 23            93                 520                0.20               0.36
# 24           132                 478                0.19               0.35
# 25           102                 684                0.26               0.39
# 26           144                 675                0.26               0.39
# 27            80                 553                0.27               0.39
# 28           200                 531                0.17               0.35
# 29            92                 705                0.22               0.38
# 30           113                 616                0.19               0.35
# 31           364                 598                0.16               0.34
# 32           152                 672                0.20               0.36
# 33           128                 584                0.12               0.31
# 34           212                 509                0.19               0.35
# 35           126                 456                0.20               0.35
# 36            70                 430                0.17               0.35
# 37           121                 485                0.21               0.37
# 38           135                 473                0.22               0.37
# 39           134                 617                0.15               0.33
# 40           127                 622                0.24               0.38
# 41            74                 446                0.19               0.36
# 42            86                 342                0.22               0.37
# 43            99                 389                0.20               0.37
# 44            65                 340                0.17               0.34
# 45           109                 665                0.17               0.35
# 46            77                 530                0.21               0.36
# 47            84                 398                0.21               0.36
# 48            88                 591                0.20               0.35
# 49           151                 530                0.23               0.38
#
#    Service Games Played  Service Games Won %  Total Points Won  \
# 0                   741                 0.88              0.55
# 1                   881                 0.85              0.54
# 2                   923                 0.85              0.54
# 3                   901                 0.87              0.54
# 4                 1,038                 0.84              0.52
# 5                   942                 0.89              0.52
# 6                   964                 0.85              0.52
# 7                   833                 0.83              0.51
# 8                   999                 0.88              0.51
# 9                   935                 0.87              0.53
# 10                  783                 0.83              0.51
# 11                  764                 0.80              0.52
# 12                  816                 0.81              0.51
# 13                  774                 0.84              0.52
# 14                  643                 0.84              0.52
# 15                  688                 0.86              0.52
# 16                  674                 0.85              0.50
# 17                  728                 0.80              0.51
# 18                  703                 0.88              0.52
# 19                  649                 0.81              0.51
# 20                  764                 0.76              0.50
# 21                  771                 0.80              0.51
# 22                  696                 0.86              0.51
# 23                  517                 0.84              0.51
# 24                  472                 0.83              0.50
# 25                  684                 0.77              0.51
# 26                  669                 0.79              0.51
# 27                  548                 0.75              0.50
# 28                  539                 0.84              0.51
# 29                  708                 0.81              0.51
# 30                  619                 0.81              0.50
# 31                  597                 0.82              0.50
# 32                  667                 0.81              0.50
# 33                  598                 0.86              0.50
# 34                  520                 0.82              0.50
# 35                  461                 0.82              0.50
# 36                  426                 0.78              0.49
# 37                  479                 0.78              0.50
# 38                  481                 0.81              0.51
# 39                  615                 0.84              0.50
# 40                  620                 0.78              0.50
# 41                  445                 0.80              0.50
# 42                  340                 0.73              0.49
# 43                  396                 0.80              0.50
# 44                  334                 0.78              0.48
# 45                  665                 0.83              0.50
# 46                  524                 0.74              0.49
# 47                  399                 0.75              0.49
# 48                  602                 0.83              0.51
# 49                  529                 0.75              0.50
#
#     Total Service Points Won
# 0                       0.70
# 1                       0.67
# 2                       0.66
# 3                       0.68
# 4                       0.66
# 5                       0.70
# 6                       0.67
# 7                       0.65
# 8                       0.69
# 9                       0.69
# 10                      0.65
# 11                      0.64
# 12                      0.65
# 13                      0.67
# 14                      0.66
# 15                      0.67
# 16                      0.67
# 17                      0.64
# 18                      0.69
# 19                      0.65
# 20                      0.61
# 21                      0.64
# 22                      0.67
# 23                      0.67
# 24                      0.65
# 25                      0.62
# 26                      0.63
# 27                      0.62
# 28                      0.67
# 29                      0.65
# 30                      0.65
# 31                      0.65
# 32                      0.64
# 33                      0.67
# 34                      0.65
# 35                      0.65
# 36                      0.64
# 37                      0.63
# 38                      0.65
# 39                      0.66
# 40                      0.63
# 41                      0.64
# 42                      0.61
# 43                      0.63
# 44                      0.62
# 45                      0.66
# 46                      0.62
# 47                      0.61
# 48                      0.66
# 49                      0.61

# %%
dfStats['Aces'] = dfStats['Aces'].str.replace(",","")
dfStats['Aces'] = dfStats['Aces'].astype("int64")
dfStats['Break Points Faced'] = dfStats['Break Points Faced'].astype("int64")
dfStats['Double Faults'] = dfStats['Double Faults'].astype("int64")
dfStats['Break Points Opportunities'] = dfStats['Break Points Opportunities'].astype("int64")
dfStats['Service Games Played'] = dfStats['Service Games Played'].str.replace(",","")
dfStats['Service Games Played'] = dfStats['Service Games Played'].astype("int64")
dfStats['Return Games Played'] = dfStats['Return Games Played'].str.replace(",","")
dfStats['Return Games Played'] = dfStats['Return Games Played'].astype("int64")
dfStats.head()
# Out:
#                     Player Name  First serve  First Serve Points Won  \
# 0                Novak Djokovic         0.64                    0.76
# 1                Carlos Alcaraz         0.66                    0.72
# 2               Daniil Medvedev         0.64                    0.75
# 3                 Jannik Sinner         0.60                    0.76
# 4                 Andrey Rublev         0.61                    0.75
# 5            Stefanos Tsitsipas         0.64                    0.78
# 6              Alexander Zverev         0.71                    0.74
# 7                   Holger Rune         0.62                    0.72
# 8                Hubert Hurkacz         0.64                    0.80
# 9                  Taylor Fritz         0.59                    0.79
# 10                  Casper Ruud         0.63                    0.71
# 11               Alex de Minaur         0.56                    0.72
# 12                   Tommy Paul         0.62                    0.72
# 13              Grigor Dimitrov         0.61                    0.77
# 14              Karen Khachanov         0.64                    0.74
# 15               Frances Tiafoe         0.60                    0.77
# 16                  Ben Shelton         0.64                    0.76
# 17               Cameron Norrie         0.65                    0.70
# 18                Nicolas Jarry         0.65                    0.77
# 19                  Ugo Humbert         0.60                    0.74
# 20          Francisco Cerundolo         0.66                    0.67
# 21             Adrian Mannarino         0.61                    0.71
# 22            Tallon Griekspoor         0.63                    0.76
# 23              Sebastian Korda         0.62                    0.74
# 24           Jan-Lennard Struff         0.59                    0.75
# 25  Alejandro Davidovich Fokina         0.66                    0.67
# 26              Lorenzo Musetti         0.62                    0.71
# 27               Sebastian Baez         0.72                    0.65
# 28        Felix Auger-Aliassime         0.60                    0.78
# 29      Tomas Martin Etcheverry         0.64                    0.71
# 30                 Jiri Lehecka         0.65                    0.72
# 31             Alexander Bublik         0.59                    0.79
# 32                  Laslo Djere         0.61                    0.72
# 33          Christopher Eubanks         0.69                    0.74
# 34               Aslan Karatsev         0.59                    0.75
# 35                  Arthur Fils         0.61                    0.74
# 36                  Borna Coric         0.60                    0.74
# 37                 Daniel Evans         0.59                    0.71
# 38              Roman Safiullin         0.64                    0.73
# 39               Alexei Popyrin         0.62                    0.76
# 40           Mackenzie McDonald         0.64                    0.69
# 41                  Andy Murray         0.61                    0.71
# 42              Sebastian Ofner         0.57                    0.71
# 43               Matteo Arnaldi         0.58                    0.69
# 44                  Max Purcell         0.60                    0.72
# 45               Lorenzo Sonego         0.66                    0.73
# 46           Yoshihito Nishioka         0.63                    0.65
# 47         Alexander Shevchenko         0.59                    0.69
# 48                Stan Wawrinka         0.56                    0.76
# 49      Botic van de Zandschulp         0.63                    0.69
#
#    1st Serve Return Points Won  2nd Serve Points Won  \
# 0                          33%                  0.58
# 1                          35%                  0.56
# 2                          34%                  0.50
# 3                          33%                  0.57
# 4                          30%                  0.51
# 5                          27%                  0.55
# 6                          29%                  0.50
# 7                          29%                  0.53
# 8                          27%                  0.51
# 9                          28%                  0.55
# 10                         30%                  0.54
# 11                         34%                  0.54
# 12                         30%                  0.53
# 13                         30%                  0.51
# 14                         30%                  0.53
# 15                         27%                  0.53
# 16                         26%                  0.52
# 17                         31%                  0.53
# 18                         28%                  0.54
# 19                         29%                  0.51
# 20                         33%                  0.49
# 21                         29%                  0.53
# 22                         27%                  0.51
# 23                         26%                  0.54
# 24                         26%                  0.50
# 25                         31%                  0.53
# 26                         32%                  0.51
# 27                         31%                  0.54
# 28                         28%                  0.49
# 29                         30%                  0.53
# 30                         28%                  0.51
# 31                         25%                  0.46
# 32                         27%                  0.52
# 33                         22%                  0.52
# 34                         27%                  0.50
# 35                         28%                  0.50
# 36                         29%                  0.49
# 37                         30%                  0.52
# 38                         29%                  0.52
# 39                         26%                  0.50
# 40                         29%                  0.51
# 41                         29%                  0.51
# 42                         29%                  0.47
# 43                         28%                  0.54
# 44                         27%                  0.47
# 45                         27%                  0.52
# 46                         26%                  0.55
# 47                         27%                  0.50
# 48                         27%                  0.54
# 49                         31%                  0.47
#
#    2nd Serve Return Points Won  Aces  Break Points Converted  \
# 0                          54%   383                    0.42
# 1                          54%   302                    0.40
# 2                          54%   547                    0.46
# 3                          54%   436                    0.42
# 4                          52%   616                    0.39
# 5                          49%   547                    0.39
# 6                          52%   613                    0.37
# 7                          49%   359                    0.39
# 8                          46%  1031                    0.35
# 9                          53%   692                    0.42
# 10                         51%   320                    0.39
# 11                         52%   229                    0.43
# 12                         51%   411                    0.37
# 13                         51%   461                    0.41
# 14                         51%   362                    0.41
# 15                         51%   459                    0.38
# 16                         44%   505                    0.41
# 17                         51%   272                    0.40
# 18                         48%   475                    0.38
# 19                         50%   341                    0.36
# 20                         51%   185                    0.40
# 21                         52%   317                    0.47
# 22                         46%   466                    0.38
# 23                         51%   355                    0.41
# 24                         49%   360                    0.38
# 25                         53%   175                    0.45
# 26                         51%   224                    0.43
# 27                         53%    97                    0.41
# 28                         47%   380                    0.32
# 29                         50%   344                    0.36
# 30                         47%   265                    0.38
# 31                         47%   543                    0.41
# 32                         50%   335                    0.38
# 33                         46%   498                    0.35
# 34                         47%   258                    0.38
# 35                         49%   245                    0.38
# 36                         45%   159                    0.35
# 37                         48%   167                    0.37
# 38                         50%   230                    0.44
# 39                         46%   466                    0.32
# 40                         53%   262                    0.43
# 41                         50%   153                    0.32
# 42                         51%   160                    0.40
# 43                         52%   167                    0.41
# 44                         46%   231                    0.37
# 45                         47%   297                    0.39
# 46                         52%    85                    0.39
# 47                         49%   140                    0.41
# 48                         47%   362                    0.39
# 49                         50%   239                    0.36
#
#     Break Points Faced  Break Points Opportunities  Break Points Saved  \
# 0                  261                         491                0.67
# 1                  369                         691                0.65
# 2                  419                         622                0.67
# 3                  368                         615                0.69
# 4                  439                         639                0.63
# 5                  312                         469                0.66
# 6                  406                         618                0.64
# 7                  395                         453                0.64
# 8                  334                         460                0.64
# 9                  352                         490                0.66
# 10                 396                         466                0.67
# 11                 374                         518                0.59
# 12                 395                         527                0.62
# 13                 337                         451                0.63
# 14                 275                         367                0.63
# 15                 275                         399                0.66
# 16                 298                         256                0.66
# 17                 401                         454                0.64
# 18                 273                         316                0.68
# 19                 315                         392                0.62
# 20                 478                         546                0.61
# 21                 393                         421                0.61
# 22                 277                         303                0.65
# 23                 225                         253                0.64
# 24                 239                         233                0.66
# 25                 411                         404                0.62
# 26                 335                         412                0.58
# 27                 332                         360                0.58
# 28                 212                         279                0.60
# 29                 354                         423                0.63
# 30                 321                         303                0.63
# 31                 278                         236                0.61
# 32                 358                         356                0.65
# 33                 247                         205                0.65
# 34                 265                         247                0.65
# 35                 224                         234                0.63
# 36                 224                         207                0.59
# 37                 272                         270                0.61
# 38                 234                         232                0.62
# 39                 284                         291                0.66
# 40                 335                         344                0.59
# 41                 228                         256                0.61
# 42                 218                         188                0.58
# 43                 249                         191                0.69
# 44                 223                         155                0.67
# 45                 326                         294                0.65
# 46                 286                         292                0.53
# 47                 246                         206                0.60
# 48                 278                         302                0.64
# 49                 354                         335                0.62
#
#     Double Faults  Return Games Played  Return Games Won %  Return Points Won  \
# 0             157                  721                0.29               0.41
# 1             161                  874                0.32               0.42
# 2             314                  922                0.31               0.41
# 3             129                  892                0.29               0.41
# 4             156                 1029                0.24               0.38
# 5             153                  926                0.20               0.35
# 6             222                  970                0.23               0.38
# 7             259                  830                0.21               0.37
# 8             133                  985                0.16               0.34
# 9             165                  909                0.23               0.38
# 10            167                  772                0.23               0.38
# 11            177                  773                0.29               0.41
# 12            143                  812                0.24               0.38
# 13            212                  758                0.24               0.38
# 14             99                  639                0.23               0.38
# 15            125                  699                0.22               0.37
# 16            209                  675                0.16               0.32
# 17            127                  718                0.25               0.39
# 18            108                  700                0.17               0.35
# 19            140                  633                0.22               0.37
# 20            218                  776                0.28               0.40
# 21            144                  777                0.26               0.38
# 22            181                  699                0.16               0.34
# 23             93                  520                0.20               0.36
# 24            132                  478                0.19               0.35
# 25            102                  684                0.26               0.39
# 26            144                  675                0.26               0.39
# 27             80                  553                0.27               0.39
# 28            200                  531                0.17               0.35
# 29             92                  705                0.22               0.38
# 30            113                  616                0.19               0.35
# 31            364                  598                0.16               0.34
# 32            152                  672                0.20               0.36
# 33            128                  584                0.12               0.31
# 34            212                  509                0.19               0.35
# 35            126                  456                0.20               0.35
# 36             70                  430                0.17               0.35
# 37            121                  485                0.21               0.37
# 38            135                  473                0.22               0.37
# 39            134                  617                0.15               0.33
# 40            127                  622                0.24               0.38
# 41             74                  446                0.19               0.36
# 42             86                  342                0.22               0.37
# 43             99                  389                0.20               0.37
# 44             65                  340                0.17               0.34
# 45            109                  665                0.17               0.35
# 46             77                  530                0.21               0.36
# 47             84                  398                0.21               0.36
# 48             88                  591                0.20               0.35
# 49            151                  530                0.23               0.38
#
#     Service Games Played  Service Games Won %  Total Points Won  \
# 0                    741                 0.88              0.55
# 1                    881                 0.85              0.54
# 2                    923                 0.85              0.54
# 3                    901                 0.87              0.54
# 4                   1038                 0.84              0.52
# 5                    942                 0.89              0.52
# 6                    964                 0.85              0.52
# 7                    833                 0.83              0.51
# 8                    999                 0.88              0.51
# 9                    935                 0.87              0.53
# 10                   783                 0.83              0.51
# 11                   764                 0.80              0.52
# 12                   816                 0.81              0.51
# 13                   774                 0.84              0.52
# 14                   643                 0.84              0.52
# 15                   688                 0.86              0.52
# 16                   674                 0.85              0.50
# 17                   728                 0.80              0.51
# 18                   703                 0.88              0.52
# 19                   649                 0.81              0.51
# 20                   764                 0.76              0.50
# 21                   771                 0.80              0.51
# 22                   696                 0.86              0.51
# 23                   517                 0.84              0.51
# 24                   472                 0.83              0.50
# 25                   684                 0.77              0.51
# 26                   669                 0.79              0.51
# 27                   548                 0.75              0.50
# 28                   539                 0.84              0.51
# 29                   708                 0.81              0.51
# 30                   619                 0.81              0.50
# 31                   597                 0.82              0.50
# 32                   667                 0.81              0.50
# 33                   598                 0.86              0.50
# 34                   520                 0.82              0.50
# 35                   461                 0.82              0.50
# 36                   426                 0.78              0.49
# 37                   479                 0.78              0.50
# 38                   481                 0.81              0.51
# 39                   615                 0.84              0.50
# 40                   620                 0.78              0.50
# 41                   445                 0.80              0.50
# 42                   340                 0.73              0.49
# 43                   396                 0.80              0.50
# 44                   334                 0.78              0.48
# 45                   665                 0.83              0.50
# 46                   524                 0.74              0.49
# 47                   399                 0.75              0.49
# 48                   602                 0.83              0.51
# 49                   529                 0.75              0.50
#
#     Total Service Points Won
# 0                       0.70
# 1                       0.67
# 2                       0.66
# 3                       0.68
# 4                       0.66
# 5                       0.70
# 6                       0.67
# 7                       0.65
# 8                       0.69
# 9                       0.69
# 10                      0.65
# 11                      0.64
# 12                      0.65
# 13                      0.67
# 14                      0.66
# 15                      0.67
# 16                      0.67
# 17                      0.64
# 18                      0.69
# 19                      0.65
# 20                      0.61
# 21                      0.64
# 22                      0.67
# 23                      0.67
# 24                      0.65
# 25                      0.62
# 26                      0.63
# 27                      0.62
# 28                      0.67
# 29                      0.65
# 30                      0.65
# 31                      0.65
# 32                      0.64
# 33                      0.67
# 34                      0.65
# 35                      0.65
# 36                      0.64
# 37                      0.63
# 38                      0.65
# 39                      0.66
# 40                      0.63
# 41                      0.64
# 42                      0.61
# 43                      0.63
# 44                      0.62
# 45                      0.66
# 46                      0.62
# 47                      0.61
# 48                      0.66
# 49                      0.61

# %%
dfStats["BreakPoints Won"] = (dfStats["Break Points Faced"] * dfStats["Break Points Converted"]).round()
dfStats["BreakPoints Saved"] = (dfStats["Break Points Opportunities"] * dfStats["Break Points Saved"]).round()
dfStats["Return Games Won"] = (dfStats["Return Games Played"] * dfStats["Return Games Won %"]).round()
dfStats["Service Games Won"] = (dfStats["Service Games Played"] * dfStats["Service Games Won %"]).round()
dfStats.head()
# Out:
#                     Player Name  First serve  First Serve Points Won  \
# 0                Novak Djokovic         0.64                    0.76
# 1                Carlos Alcaraz         0.66                    0.72
# 2               Daniil Medvedev         0.64                    0.75
# 3                 Jannik Sinner         0.60                    0.76
# 4                 Andrey Rublev         0.61                    0.75
# 5            Stefanos Tsitsipas         0.64                    0.78
# 6              Alexander Zverev         0.71                    0.74
# 7                   Holger Rune         0.62                    0.72
# 8                Hubert Hurkacz         0.64                    0.80
# 9                  Taylor Fritz         0.59                    0.79
# 10                  Casper Ruud         0.63                    0.71
# 11               Alex de Minaur         0.56                    0.72
# 12                   Tommy Paul         0.62                    0.72
# 13              Grigor Dimitrov         0.61                    0.77
# 14              Karen Khachanov         0.64                    0.74
# 15               Frances Tiafoe         0.60                    0.77
# 16                  Ben Shelton         0.64                    0.76
# 17               Cameron Norrie         0.65                    0.70
# 18                Nicolas Jarry         0.65                    0.77
# 19                  Ugo Humbert         0.60                    0.74
# 20          Francisco Cerundolo         0.66                    0.67
# 21             Adrian Mannarino         0.61                    0.71
# 22            Tallon Griekspoor         0.63                    0.76
# 23              Sebastian Korda         0.62                    0.74
# 24           Jan-Lennard Struff         0.59                    0.75
# 25  Alejandro Davidovich Fokina         0.66                    0.67
# 26              Lorenzo Musetti         0.62                    0.71
# 27               Sebastian Baez         0.72                    0.65
# 28        Felix Auger-Aliassime         0.60                    0.78
# 29      Tomas Martin Etcheverry         0.64                    0.71
# 30                 Jiri Lehecka         0.65                    0.72
# 31             Alexander Bublik         0.59                    0.79
# 32                  Laslo Djere         0.61                    0.72
# 33          Christopher Eubanks         0.69                    0.74
# 34               Aslan Karatsev         0.59                    0.75
# 35                  Arthur Fils         0.61                    0.74
# 36                  Borna Coric         0.60                    0.74
# 37                 Daniel Evans         0.59                    0.71
# 38              Roman Safiullin         0.64                    0.73
# 39               Alexei Popyrin         0.62                    0.76
# 40           Mackenzie McDonald         0.64                    0.69
# 41                  Andy Murray         0.61                    0.71
# 42              Sebastian Ofner         0.57                    0.71
# 43               Matteo Arnaldi         0.58                    0.69
# 44                  Max Purcell         0.60                    0.72
# 45               Lorenzo Sonego         0.66                    0.73
# 46           Yoshihito Nishioka         0.63                    0.65
# 47         Alexander Shevchenko         0.59                    0.69
# 48                Stan Wawrinka         0.56                    0.76
# 49      Botic van de Zandschulp         0.63                    0.69
#
#    1st Serve Return Points Won  2nd Serve Points Won  \
# 0                          33%                  0.58
# 1                          35%                  0.56
# 2                          34%                  0.50
# 3                          33%                  0.57
# 4                          30%                  0.51
# 5                          27%                  0.55
# 6                          29%                  0.50
# 7                          29%                  0.53
# 8                          27%                  0.51
# 9                          28%                  0.55
# 10                         30%                  0.54
# 11                         34%                  0.54
# 12                         30%                  0.53
# 13                         30%                  0.51
# 14                         30%                  0.53
# 15                         27%                  0.53
# 16                         26%                  0.52
# 17                         31%                  0.53
# 18                         28%                  0.54
# 19                         29%                  0.51
# 20                         33%                  0.49
# 21                         29%                  0.53
# 22                         27%                  0.51
# 23                         26%                  0.54
# 24                         26%                  0.50
# 25                         31%                  0.53
# 26                         32%                  0.51
# 27                         31%                  0.54
# 28                         28%                  0.49
# 29                         30%                  0.53
# 30                         28%                  0.51
# 31                         25%                  0.46
# 32                         27%                  0.52
# 33                         22%                  0.52
# 34                         27%                  0.50
# 35                         28%                  0.50
# 36                         29%                  0.49
# 37                         30%                  0.52
# 38                         29%                  0.52
# 39                         26%                  0.50
# 40                         29%                  0.51
# 41                         29%                  0.51
# 42                         29%                  0.47
# 43                         28%                  0.54
# 44                         27%                  0.47
# 45                         27%                  0.52
# 46                         26%                  0.55
# 47                         27%                  0.50
# 48                         27%                  0.54
# 49                         31%                  0.47
#
#    2nd Serve Return Points Won  Aces  Break Points Converted  \
# 0                          54%   383                    0.42
# 1                          54%   302                    0.40
# 2                          54%   547                    0.46
# 3                          54%   436                    0.42
# 4                          52%   616                    0.39
# 5                          49%   547                    0.39
# 6                          52%   613                    0.37
# 7                          49%   359                    0.39
# 8                          46%  1031                    0.35
# 9                          53%   692                    0.42
# 10                         51%   320                    0.39
# 11                         52%   229                    0.43
# 12                         51%   411                    0.37
# 13                         51%   461                    0.41
# 14                         51%   362                    0.41
# 15                         51%   459                    0.38
# 16                         44%   505                    0.41
# 17                         51%   272                    0.40
# 18                         48%   475                    0.38
# 19                         50%   341                    0.36
# 20                         51%   185                    0.40
# 21                         52%   317                    0.47
# 22                         46%   466                    0.38
# 23                         51%   355                    0.41
# 24                         49%   360                    0.38
# 25                         53%   175                    0.45
# 26                         51%   224                    0.43
# 27                         53%    97                    0.41
# 28                         47%   380                    0.32
# 29                         50%   344                    0.36
# 30                         47%   265                    0.38
# 31                         47%   543                    0.41
# 32                         50%   335                    0.38
# 33                         46%   498                    0.35
# 34                         47%   258                    0.38
# 35                         49%   245                    0.38
# 36                         45%   159                    0.35
# 37                         48%   167                    0.37
# 38                         50%   230                    0.44
# 39                         46%   466                    0.32
# 40                         53%   262                    0.43
# 41                         50%   153                    0.32
# 42                         51%   160                    0.40
# 43                         52%   167                    0.41
# 44                         46%   231                    0.37
# 45                         47%   297                    0.39
# 46                         52%    85                    0.39
# 47                         49%   140                    0.41
# 48                         47%   362                    0.39
# 49                         50%   239                    0.36
#
#     Break Points Faced  Break Points Opportunities  Break Points Saved  \
# 0                  261                         491                0.67
# 1                  369                         691                0.65
# 2                  419                         622                0.67
# 3                  368                         615                0.69
# 4                  439                         639                0.63
# 5                  312                         469                0.66
# 6                  406                         618                0.64
# 7                  395                         453                0.64
# 8                  334                         460                0.64
# 9                  352                         490                0.66
# 10                 396                         466                0.67
# 11                 374                         518                0.59
# 12                 395                         527                0.62
# 13                 337                         451                0.63
# 14                 275                         367                0.63
# 15                 275                         399                0.66
# 16                 298                         256                0.66
# 17                 401                         454                0.64
# 18                 273                         316                0.68
# 19                 315                         392                0.62
# 20                 478                         546                0.61
# 21                 393                         421                0.61
# 22                 277                         303                0.65
# 23                 225                         253                0.64
# 24                 239                         233                0.66
# 25                 411                         404                0.62
# 26                 335                         412                0.58
# 27                 332                         360                0.58
# 28                 212                         279                0.60
# 29                 354                         423                0.63
# 30                 321                         303                0.63
# 31                 278                         236                0.61
# 32                 358                         356                0.65
# 33                 247                         205                0.65
# 34                 265                         247                0.65
# 35                 224                         234                0.63
# 36                 224                         207                0.59
# 37                 272                         270                0.61
# 38                 234                         232                0.62
# 39                 284                         291                0.66
# 40                 335                         344                0.59
# 41                 228                         256                0.61
# 42                 218                         188                0.58
# 43                 249                         191                0.69
# 44                 223                         155                0.67
# 45                 326                         294                0.65
# 46                 286                         292                0.53
# 47                 246                         206                0.60
# 48                 278                         302                0.64
# 49                 354                         335                0.62
#
#     Double Faults  Return Games Played  Return Games Won %  Return Points Won  \
# 0             157                  721                0.29               0.41
# 1             161                  874                0.32               0.42
# 2             314                  922                0.31               0.41
# 3             129                  892                0.29               0.41
# 4             156                 1029                0.24               0.38
# 5             153                  926                0.20               0.35
# 6             222                  970                0.23               0.38
# 7             259                  830                0.21               0.37
# 8             133                  985                0.16               0.34
# 9             165                  909                0.23               0.38
# 10            167                  772                0.23               0.38
# 11            177                  773                0.29               0.41
# 12            143                  812                0.24               0.38
# 13            212                  758                0.24               0.38
# 14             99                  639                0.23               0.38
# 15            125                  699                0.22               0.37
# 16            209                  675                0.16               0.32
# 17            127                  718                0.25               0.39
# 18            108                  700                0.17               0.35
# 19            140                  633                0.22               0.37
# 20            218                  776                0.28               0.40
# 21            144                  777                0.26               0.38
# 22            181                  699                0.16               0.34
# 23             93                  520                0.20               0.36
# 24            132                  478                0.19               0.35
# 25            102                  684                0.26               0.39
# 26            144                  675                0.26               0.39
# 27             80                  553                0.27               0.39
# 28            200                  531                0.17               0.35
# 29             92                  705                0.22               0.38
# 30            113                  616                0.19               0.35
# 31            364                  598                0.16               0.34
# 32            152                  672                0.20               0.36
# 33            128                  584                0.12               0.31
# 34            212                  509                0.19               0.35
# 35            126                  456                0.20               0.35
# 36             70                  430                0.17               0.35
# 37            121                  485                0.21               0.37
# 38            135                  473                0.22               0.37
# 39            134                  617                0.15               0.33
# 40            127                  622                0.24               0.38
# 41             74                  446                0.19               0.36
# 42             86                  342                0.22               0.37
# 43             99                  389                0.20               0.37
# 44             65                  340                0.17               0.34
# 45            109                  665                0.17               0.35
# 46             77                  530                0.21               0.36
# 47             84                  398                0.21               0.36
# 48             88                  591                0.20               0.35
# 49            151                  530                0.23               0.38
#
#     Service Games Played  Service Games Won %  Total Points Won  \
# 0                    741                 0.88              0.55
# 1                    881                 0.85              0.54
# 2                    923                 0.85              0.54
# 3                    901                 0.87              0.54
# 4                   1038                 0.84              0.52
# 5                    942                 0.89              0.52
# 6                    964                 0.85              0.52
# 7                    833                 0.83              0.51
# 8                    999                 0.88              0.51
# 9                    935                 0.87              0.53
# 10                   783                 0.83              0.51
# 11                   764                 0.80              0.52
# 12                   816                 0.81              0.51
# 13                   774                 0.84              0.52
# 14                   643                 0.84              0.52
# 15                   688                 0.86              0.52
# 16                   674                 0.85              0.50
# 17                   728                 0.80              0.51
# 18                   703                 0.88              0.52
# 19                   649                 0.81              0.51
# 20                   764                 0.76              0.50
# 21                   771                 0.80              0.51
# 22                   696                 0.86              0.51
# 23                   517                 0.84              0.51
# 24                   472                 0.83              0.50
# 25                   684                 0.77              0.51
# 26                   669                 0.79              0.51
# 27                   548                 0.75              0.50
# 28                   539                 0.84              0.51
# 29                   708                 0.81              0.51
# 30                   619                 0.81              0.50
# 31                   597                 0.82              0.50
# 32                   667                 0.81              0.50
# 33                   598                 0.86              0.50
# 34                   520                 0.82              0.50
# 35                   461                 0.82              0.50
# 36                   426                 0.78              0.49
# 37                   479                 0.78              0.50
# 38                   481                 0.81              0.51
# 39                   615                 0.84              0.50
# 40                   620                 0.78              0.50
# 41                   445                 0.80              0.50
# 42                   340                 0.73              0.49
# 43                   396                 0.80              0.50
# 44                   334                 0.78              0.48
# 45                   665                 0.83              0.50
# 46                   524                 0.74              0.49
# 47                   399                 0.75              0.49
# 48                   602                 0.83              0.51
# 49                   529                 0.75              0.50
#
#     Total Service Points Won  BreakPoints Won  BreakPoints Saved  \
# 0                       0.70            110.0              329.0
# 1                       0.67            148.0              449.0
# 2                       0.66            193.0              417.0
# 3                       0.68            155.0              424.0
# 4                       0.66            171.0              403.0
# 5                       0.70            122.0              310.0
# 6                       0.67            150.0              396.0
# 7                       0.65            154.0              290.0
# 8                       0.69            117.0              294.0
# 9                       0.69            148.0              323.0
# 10                      0.65            154.0              312.0
# 11                      0.64            161.0              306.0
# 12                      0.65            146.0              327.0
# 13                      0.67            138.0              284.0
# 14                      0.66            113.0              231.0
# 15                      0.67            104.0              263.0
# 16                      0.67            122.0              169.0
# 17                      0.64            160.0              291.0
# 18                      0.69            104.0              215.0
# 19                      0.65            113.0              243.0
# 20                      0.61            191.0              333.0
# 21                      0.64            185.0              257.0
# 22                      0.67            105.0              197.0
# 23                      0.67             92.0              162.0
# 24                      0.65             91.0              154.0
# 25                      0.62            185.0              250.0
# 26                      0.63            144.0              239.0
# 27                      0.62            136.0              209.0
# 28                      0.67             68.0              167.0
# 29                      0.65            127.0              266.0
# 30                      0.65            122.0              191.0
# 31                      0.65            114.0              144.0
# 32                      0.64            136.0              231.0
# 33                      0.67             86.0              133.0
# 34                      0.65            101.0              161.0
# 35                      0.65             85.0              147.0
# 36                      0.64             78.0              122.0
# 37                      0.63            101.0              165.0
# 38                      0.65            103.0              144.0
# 39                      0.66             91.0              192.0
# 40                      0.63            144.0              203.0
# 41                      0.64             73.0              156.0
# 42                      0.61             87.0              109.0
# 43                      0.63            102.0              132.0
# 44                      0.62             83.0              104.0
# 45                      0.66            127.0              191.0
# 46                      0.62            112.0              155.0
# 47                      0.61            101.0              124.0
# 48                      0.66            108.0              193.0
# 49                      0.61            127.0              208.0
#
#     Return Games Won  Service Games Won
# 0              209.0              652.0
# 1              280.0              749.0
# 2              286.0              785.0
# 3              259.0              784.0
# 4              247.0              872.0
# 5              185.0              838.0
# 6              223.0              819.0
# 7              174.0              691.0
# 8              158.0              879.0
# 9              209.0              813.0
# 10             178.0              650.0
# 11             224.0              611.0
# 12             195.0              661.0
# 13             182.0              650.0
# 14             147.0              540.0
# 15             154.0              592.0
# 16             108.0              573.0
# 17             180.0              582.0
# 18             119.0              619.0
# 19             139.0              526.0
# 20             217.0              581.0
# 21             202.0              617.0
# 22             112.0              599.0
# 23             104.0              434.0
# 24              91.0              392.0
# 25             178.0              527.0
# 26             176.0              529.0
# 27             149.0              411.0
# 28              90.0              453.0
# 29             155.0              573.0
# 30             117.0              501.0
# 31              96.0              490.0
# 32             134.0              540.0
# 33              70.0              514.0
# 34              97.0              426.0
# 35              91.0              378.0
# 36              73.0              332.0
# 37             102.0              374.0
# 38             104.0              390.0
# 39              93.0              517.0
# 40             149.0              484.0
# 41              85.0              356.0
# 42              75.0              248.0
# 43              78.0              317.0
# 44              58.0              261.0
# 45             113.0              552.0
# 46             111.0              388.0
# 47              84.0              299.0
# 48             118.0              500.0
# 49             122.0              397.0

# %% [markdown]
# ### Análisis univariante

# %%
dfStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Player Name                  50 non-null     object
#  1   First serve                  50 non-null     float64
#  2   First Serve Points Won       50 non-null     float64
#  3   1st Serve Return Points Won  50 non-null     object
#  4   2nd Serve Points Won         50 non-null     float64
#  5   2nd Serve Return Points Won  50 non-null     object
#  6   Aces                         50 non-null     int64
#  7   Break Points Converted       50 non-null     float64
#  8   Break Points Faced           50 non-null     int64
#  9   Break Points Opportunities   50 non-null     int64
#  10  Break Points Saved           50 non-null     float64
#  11  Double Faults                50 non-null     int64
#  12  Return Games Played          50 non-null     int64
#  13  Return Games Won %           50 non-null     float64
#  14  Return Points Won            50 non-null     float64
#  15  Service Games Played         50 non-null     int64
#  16  Service Games Won %          50 non-null     float64
#  17  Total Points Won             50 non-null     float64
#  18  Total Service Points Won     50 non-null     float64
#  19  BreakPoints Won              50 non-null     float64
#  20  BreakPoints Saved            50 non-null     float64
#  21  Return Games Won             50 non-null     float64
#  22  Service Games Won            50 non-null     float64
# dtypes: float64(14), int64(6), object(3)
# memory usage: 9.1+ KB

# %%
dfStats.head()
# Out:
#        Player Name  First serve  First Serve Points Won  \
# 0   Novak Djokovic         0.64                    0.76
# 1   Carlos Alcaraz         0.66                    0.72
# 2  Daniil Medvedev         0.64                    0.75
# 3    Jannik Sinner         0.60                    0.76
# 4    Andrey Rublev         0.61                    0.75
#
#   1st Serve Return Points Won  2nd Serve Points Won  \
# 0                         33%                  0.58
# 1                         35%                  0.56
# 2                         34%                  0.50
# 3                         33%                  0.57
# 4                         30%                  0.51
#
#   2nd Serve Return Points Won  Aces  Break Points Converted  \
# 0                         54%   383                    0.42
# 1                         54%   302                    0.40
# 2                         54%   547                    0.46
# 3                         54%   436                    0.42
# 4                         52%   616                    0.39
#
#    Break Points Faced  Break Points Opportunities  Break Points Saved  \
# 0                 261                         491                0.67
# 1                 369                         691                0.65
# 2                 419                         622                0.67
# 3                 368                         615                0.69
# 4                 439                         639                0.63
#
#    Double Faults  Return Games Played  Return Games Won %  Return Points Won  \
# 0            157                  721                0.29               0.41
# 1            161                  874                0.32               0.42
# 2            314                  922                0.31               0.41
# 3            129                  892                0.29               0.41
# 4            156                 1029                0.24               0.38
#
#    Service Games Played  Service Games Won %  Total Points Won  \
# 0                   741                 0.88              0.55
# 1                   881                 0.85              0.54
# 2                   923                 0.85              0.54
# 3                   901                 0.87              0.54
# 4                  1038                 0.84              0.52
#
#    Total Service Points Won  BreakPoints Won  BreakPoints Saved  \
# 0                      0.70            110.0              329.0
# 1                      0.67            148.0              449.0
# 2                      0.66            193.0              417.0
# 3                      0.68            155.0              424.0
# 4                      0.66            171.0              403.0
#
#    Return Games Won  Service Games Won
# 0             209.0              652.0
# 1             280.0              749.0
# 2             286.0              785.0
# 3             259.0              784.0
# 4             247.0              872.0

# %%
for i in dfStats.select_dtypes(include=object):
    print(f"La cardinalidad de la variable {i} es {(dfStats[i].nunique()/dfStats.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable Player Name es 100.00%
# La cardinalidad de la variable 1st Serve Return Points Won es 24.00%
# La cardinalidad de la variable 2nd Serve Return Points Won es 22.00%

# %%
for i in dfStats.select_dtypes(include=["int64", "float64"]):
    print(f"La cardinalidad de la variable {i} es {(dfStats[i].nunique()/dfStats.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable First serve es 28.00%
# La cardinalidad de la variable First Serve Points Won es 28.00%
# La cardinalidad de la variable 2nd Serve Points Won es 24.00%
# La cardinalidad de la variable Aces es 92.00%
# La cardinalidad de la variable Break Points Converted es 28.00%
# La cardinalidad de la variable Break Points Faced es 88.00%
# La cardinalidad de la variable Break Points Opportunities es 96.00%
# La cardinalidad de la variable Break Points Saved es 26.00%
# La cardinalidad de la variable Double Faults es 92.00%
# La cardinalidad de la variable Return Games Played es 94.00%
# La cardinalidad de la variable Return Games Won % es 34.00%
# La cardinalidad de la variable Return Points Won es 24.00%
# La cardinalidad de la variable Service Games Played es 98.00%
# La cardinalidad de la variable Service Games Won % es 34.00%
# La cardinalidad de la variable Total Points Won es 16.00%
# La cardinalidad de la variable Total Service Points Won es 20.00%
# La cardinalidad de la variable BreakPoints Won es 72.00%
# La cardinalidad de la variable BreakPoints Saved es 94.00%
# La cardinalidad de la variable Return Games Won es 90.00%
# La cardinalidad de la variable Service Games Won es 94.00%

# %%
dfStats.hist(figsize=(20,15),grid=False,color="#1DB954");

# %%
dfStats.describe().round(2)
# Out:
#        First serve  First Serve Points Won  2nd Serve Points Won     Aces  \
# count        50.00                   50.00                 50.00    50.00
# mean          0.62                    0.73                  0.52   350.52
# std           0.03                    0.04                  0.03   174.71
# min           0.56                    0.65                  0.46    85.00
# 25%           0.60                    0.71                  0.50   230.25
# 50%           0.62                    0.74                  0.52   338.00
# 75%           0.64                    0.76                  0.54   460.50
# max           0.72                    0.80                  0.58  1031.00
#
#        Break Points Converted  Break Points Faced  Break Points Opportunities  \
# count                   50.00                50.0                       50.00
# mean                     0.39               314.0                      369.44
# std                      0.03                67.9                      135.57
# min                      0.32               212.0                      155.00
# 25%                      0.37               262.0                      256.00
# 50%                      0.39               313.5                      350.00
# 75%                      0.41               365.5                      458.50
# max                      0.47               478.0                      691.00
#
#        Break Points Saved  Double Faults  Return Games Played  \
# count               50.00          50.00                50.00
# mean                 0.63         145.14               658.56
# std                  0.03          59.85               173.65
# min                  0.53          65.00               340.00
# 25%                  0.61         103.50               530.00
# 50%                  0.64         133.50               668.50
# 75%                  0.66         164.00               772.75
# max                  0.69         364.00              1029.00
#
#        Return Games Won %  Return Points Won  Service Games Played  \
# count               50.00              50.00                 50.00
# mean                 0.22               0.37                661.28
# std                  0.04               0.02                176.30
# min                  0.12               0.31                334.00
# 25%                  0.19               0.35                525.25
# 50%                  0.22               0.37                666.00
# 75%                  0.24               0.38                769.25
# max                  0.32               0.42               1038.00
#
#        Service Games Won %  Total Points Won  Total Service Points Won  \
# count                50.00             50.00                     50.00
# mean                  0.82              0.51                      0.65
# std                   0.04              0.01                      0.02
# min                   0.73              0.48                      0.61
# 25%                   0.80              0.50                      0.64
# 50%                   0.82              0.51                      0.65
# 75%                   0.85              0.52                      0.67
# max                   0.89              0.55                      0.70
#
#        BreakPoints Won  BreakPoints Saved  Return Games Won  Service Games Won
# count            50.00              50.00             50.00              50.00
# mean            123.76             234.30            146.00             545.32
# std              31.84              89.64             58.12             161.64
# min              68.00             104.00             58.00             248.00
# 25%             101.25             161.25             98.25             414.75
# 50%             119.50             212.00            136.50             534.50
# 75%             147.50             293.25            181.50             642.25
# max             193.00             449.00            286.00             879.00

# %% [markdown]
# ### Análisis bivariante

# %%
sns.jointplot(x=dfStats["Service Games Won %"], y=dfStats["Aces"], kind='scatter',
              color='blue', edgecolor="skyblue", linewidth=2, s=200)

plt.show();

# %% [markdown]
# ### Análisis multivariante

# %%
from math import pi

dfStats_values = dfStats.head()[["Player Name","Aces", "Double Faults","BreakPoints Won", "BreakPoints Saved", "Return Games Won", "Service Games Won"]]

# number of variable
categories=list(dfStats_values)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, projection="polar")
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([100,300,600, 900], ["100","300","600", "900"], color="grey", size=7)
plt.ylim(0,900)
 

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't make a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=dfStats_values.loc[0].drop('Player Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Djokovic")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=dfStats_values.loc[1].drop('Player Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Alcaraz")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=dfStats_values.loc[2].drop('Player Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Sinner")
ax.fill(angles, values, 'g', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Show the graph
plt.show()

# %%
def make_spider( row, title, color):

    # number of variable
    categories=list(dfStats_values)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(1,2,row +1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([100,300,600, 850], ["100","300","600", "850"], color="grey", size=7)
    plt.ylim(0,850)

    # Ind1
    values=dfStats_values.loc[row].drop('Player Name').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=10, color=color, y=1.1)

    
# ------- PART 2: Apply the function to all individuals
# initialize the figure
my_dpi=150
plt.figure(figsize=(1500/my_dpi, 2500/my_dpi), dpi=my_dpi)
 
# Create a color palette:
colores = ["b", "g", "r"]

# Loop to plot
for row in range(0, len(dfStats_values.head(2).index)):
    col = colores[row]
    make_spider( row=row, title=dfStats_values['Player Name'][row],color=col)

# %%
# 1. Relacion entre el número de aces y el numero de juegos ganados al saque

df_aces = dfStats["Aces"]
df_DobleFalta = dfStats["Service Games Won"]

correlacion , pv = stats.pearsonr(df_aces, df_DobleFalta)
correlacion, pv


if pv < 0.05:
    print('Rechazamos la hipótesis nula "No hay evidencia significativa en la correlación entre número de aces y el número de servicios ganados"')
else:
    print('No rechazamos la hipótesis nula')
# Out:
# Rechazamos la hipótesis nula "No hay evidencia significativa en la correlación entre número de aces y el número de servicios ganados"

# %%
# 2. Relacion entre el número de DF y el numero de juegos perdidos al saque

df_aces = dfStats["Double Faults"]

df_DobleFalta = dfStats["BreakPoints Saved"]

ttest = stats.ttest_ind(df_aces, df_DobleFalta)


if ttest[1] < 0.05:
    print('Rechazamos la hipótesis nula "No hay evidencia significativa en la masa corporal entre sexos de los pingüino"')
else:
    print('No rechazamos la hipótesis nula')
# Out:
# Rechazamos la hipótesis nula "No hay evidencia significativa en la masa corporal entre sexos de los pingüino"

# %%
#4.
variables_num = dfStats.select_dtypes(exclude='object')

shapiro = {var: stats.shapiro(variables_num[var]) for var in variables_num.columns}

for var in variables_num.columns:
    if shapiro[var][1] < 0.05:
        print(f'Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable {var}"')
    else:
        print(f'No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable {var}"')
# Out:
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable First serve"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable First Serve Points Won"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable 2nd Serve Points Won"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Aces"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Break Points Converted"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Break Points Faced"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Break Points Opportunities"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Break Points Saved"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Double Faults"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Return Games Played"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Return Games Won %"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Return Points Won"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Service Games Played"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Service Games Won %"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Total Points Won"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Total Service Points Won"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable BreakPoints Won"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable BreakPoints Saved"
# Rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Return Games Won"
# No rechazamos la hipótesis nula "No hay evidencia significativa en la normalidad de la variable Service Games Won"
